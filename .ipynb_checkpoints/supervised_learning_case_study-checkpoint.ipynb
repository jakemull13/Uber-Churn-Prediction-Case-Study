# %% [markdown]
# # Case Study:

# %% [markdown]
# ## Import Data

# %%
df = pd.read_csv('data/churn.csv')
df

df_train = pd.read_csv('data/churn_train.csv')
df_train

df_test = pd.read_csv('data/churn_test.csv')
df_test
# Out:
#        avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0          3.67                   5.0                   4.7       1.10
# 1          8.26                   5.0                   5.0       1.00
# 2          0.77                   5.0                   4.3       1.00
# 3          2.36                   4.9                   4.6       1.14
# 4          3.13                   4.9                   4.4       1.19
# ...         ...                   ...                   ...        ...
# 49995      5.63                   4.2                   5.0       1.00
# 49996      0.00                   4.0                   NaN       1.00
# 49997      3.86                   5.0                   5.0       1.00
# 49998      4.58                   3.5                   3.0       1.00
# 49999      3.49                   5.0                   NaN       1.00
#
#                  city last_trip_date    phone signup_date  surge_pct  \
# ...

# %% [markdown]
# ## Clean Data

# %%
def convert_to_boolean(X, features):
    pass

def convert_to_int(X, features):
    pass

def convert_to_categorical(X, features):
    pass

# %%
df.dtypes
# Out:
# avg_dist                  float64
# avg_rating_by_driver      float64
# avg_rating_of_driver      float64
# avg_surge                 float64
# city                       object
# last_trip_date             object
# phone                      object
# signup_date                object
# surge_pct                 float64
# trips_in_first_30_days      int64
# luxury_car_user              bool
# weekday_pct               float64
# dtype: object

# %%
df['phone'] = df['phone'].apply(lambda x: x == 'Android')
df.dropna(inplace=True)
df.reset_index()
# Out:
#        index  avg_dist  avg_rating_by_driver  avg_rating_of_driver  avg_surge  \
# 0          0      3.67                   5.0                   4.7       1.10
# 1          1      8.26                   5.0                   5.0       1.00
# 2          2      0.77                   5.0                   4.3       1.00
# 3          3      2.36                   4.9                   4.6       1.14
# 4          4      3.13                   4.9                   4.4       1.19
# ...      ...       ...                   ...                   ...        ...
# 41739  49993      2.53                   4.7                   4.8       1.11
# 41740  49994      2.25                   4.5                   4.6       1.44
# 41741  49995      5.63                   4.2                   5.0       1.00
# 41742  49997      3.86                   5.0                   5.0       1.00
# 41743  49998      4.58                   3.5                   3.0       1.00
#
# ...

# %% [markdown]
# ## EDA

# %%
import seaborn as sns

def plot_correlation_matrix(X):
    corr = X.corr()
    ax = sns.heatmap(
        corr, 
        vmin=-1, vmax=1, center=0,
        cmap=sns.diverging_palette(20, 220, n=200),
        square=True
    )
    ax.set_xticklabels(
        ax.get_xticklabels(),
        rotation=45,
        horizontalalignment='right'
    );
    return 

def plot_logistic_regression(X, feature, y):
    pass

def get_p_values(X, y):
    pass

# %%
plot_correlation_matrix(df)

# %% [markdown]
# ## Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
#logistic
def train_logistic_model(X, y):
    model = LogisticRegression()
    X_train, X_valid, y_train, y_valid = train_test_split(X, y)
    model.fit(X_train, y_train)
    coeffs = model.coeffs
    y_predict = model.predict(X_valid)
    score = mean_squared_errpr(y_valid, y_predict)
    return pd.DataFrame(coeffs, columns = X.columns), score

#random forest
def train_random_forest(X, y):
    pass
    
#neural net
def train_neural_model(X, y):
    pass

# %% [markdown]
# train_logistic_model(

# %% [markdown]
# ## Tune
